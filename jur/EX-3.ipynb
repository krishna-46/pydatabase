# %% [markdown]
# Using the dataframe created in the Exercise - 2, perform the following:

# %%
import pandas as pd

# %%
drug_df = pd.read_csv('Dataset/drug.csv')
drug_df.head()
# Out:
#               urlDrugName  rating         effectiveness          sideEffects  \
# 0  2202         enalapril       4      Highly Effective    Mild Side Effects
# 1  3117  ortho-tri-cyclen       1      Highly Effective  Severe Side Effects
# 2  1146           ponstel      10      Highly Effective      No Side Effects
# 3  3947          prilosec       3  Marginally Effective    Mild Side Effects
# 4  1951            lyrica       2  Marginally Effective  Severe Side Effects
#
#                                 condition  \
# 0  management of congestive heart failure
# 1                        birth prevention
# 2                        menstrual cramps
# 3                             acid reflux
# 4                            fibromyalgia
#
#                                       benefitsReview  \
# 0  slowed the progression of left ventricular dys...
# 1  Although this type of birth control has more c...
# 2  I was used to having cramps so badly that they...
# ...

# %% [markdown]
# 1. Return the number of rows in the dataframe.

# %%
drug_df.shape
# Out:
# (3107, 9)

# %% [markdown]
# 2. Find the number of missing values in each column.

# %%
drug_df.isnull().sum()
# Out:
#                      0
# urlDrugName          0
# rating               0
# effectiveness        0
# sideEffects          0
# condition            1
# benefitsReview       0
# sideEffectsReview    2
# commentsReview       8
# dtype: int64

# %% [markdown]
# 3. If there are any missing values in the column 'condition', fill them with 'No condition specified'.

# %%
# thir are no null val

drug_df.fillna('no').head()
# Out:
#               urlDrugName  rating         effectiveness          sideEffects  \
# 0  2202         enalapril       4      Highly Effective    Mild Side Effects
# 1  3117  ortho-tri-cyclen       1      Highly Effective  Severe Side Effects
# 2  1146           ponstel      10      Highly Effective      No Side Effects
# 3  3947          prilosec       3  Marginally Effective    Mild Side Effects
# 4  1951            lyrica       2  Marginally Effective  Severe Side Effects
#
#                                 condition  \
# 0  management of congestive heart failure
# 1                        birth prevention
# 2                        menstrual cramps
# 3                             acid reflux
# 4                            fibromyalgia
#
#                                       benefitsReview  \
# 0  slowed the progression of left ventricular dys...
# 1  Although this type of birth control has more c...
# 2  I was used to having cramps so badly that they...
# ...

# %% [markdown]
# 4. Display all the rows which have 'Highly Effective' or 'Considerably Effective' in the 'effectiveness' column.

# %%
Highly_Effective=drug_df [drug_df['effectiveness'].isin(['Highly Effective'])]
Highly_Effective.head()
# Out:
#               urlDrugName  rating     effectiveness          sideEffects  \
# 0  2202         enalapril       4  Highly Effective    Mild Side Effects
# 1  3117  ortho-tri-cyclen       1  Highly Effective  Severe Side Effects
# 2  1146           ponstel      10  Highly Effective      No Side Effects
# 6  1043           vyvanse       9  Highly Effective    Mild Side Effects
# 8  1591             xanax      10  Highly Effective      No Side Effects
#
#                                 condition  \
# 0  management of congestive heart failure
# 1                        birth prevention
# 2                        menstrual cramps
# 6                                     add
# 8                          panic disorder
#
#                                       benefitsReview  \
# 0  slowed the progression of left ventricular dys...
# 1  Although this type of birth control has more c...
# 2  I was used to having cramps so badly that they...
# ...

# %% [markdown]
# 5. Create a column 'Side_Effect_Rating'. Follow the below rules to fill this column from the data points in 'SideEffects' column.

# %%
 drug_df['sideEffects']=drug_df['Side_Effect_Rating']=
drug_df.loc[:['sideEffects']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 drug_df['sideEffects']=drug_df['Side_Effect_Rating']=1,2,3,4,5
#       2 drug_df.loc[:['sideEffects']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
# ...
